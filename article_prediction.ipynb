# %%
#importing libraries

import pandas as pd
import numpy as np
import pandas_profiling
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

# %%
#loading  and copying post data

post_data = pd.read_csv('posts.csv')
post_data2 = post_data.copy()
post_data2.head(5)
# Out:
#    id  user_id                              title  \
# 0   1     2077  What i have learnt so far on HTML
# 1   2     1719                   HTML BEGINS HERE
# 2   4     1310            My Laziness In The Open
# 3   6     1787                          MY TASK 2
# 4   7      167                             Task 2
#
#                                              content        tags  \
# 0  I learnt how to use the table tag as i have us...         NaN
# 1   I am on this journey with start.ng, and here ...  Technology
# 2  I have not been attending classes on the HNG c...         NaN
# 3  My journey on **StartNG** pre-internship progr...         NaN
# 4   A Summary on The “idongesit.html” CV, Its Str...         NaN
#
#                                     slug       created_at       updated_at  \
# 0  what-i-have-learnt-so-far-on-html-985  8/25/2019 19:39  8/28/2019 11:30
# 1                   html-begins-here-4d6  8/25/2019 19:44  8/28/2019 11:30
# 2            my-laziness-in-the-open-029  8/25/2019 19:50  8/28/2019 11:30
# 3                          my-task-2-649  8/25/2019 19:51  8/28/2019 11:30
# 4                             task-2-7e5  8/25/2019 19:51  8/28/2019 11:30
#
#   image  status_id action  post_id
# 0     1        NaN    NaN      NaN
# 1     1        NaN    NaN      NaN
# 2     1        NaN    NaN      NaN
# 3     1        NaN    NaN      NaN
# 4     1        NaN    NaN      NaN

# %%
#understanding data

post_data2.dtypes
# Out:
# id              int64
# user_id         int64
# title          object
# content        object
# tags           object
# slug           object
# created_at     object
# updated_at     object
# image          object
# status_id     float64
# action         object
# post_id       float64
# dtype: object

# %%
#Loading and copying user data

user_data = pd.read_csv('users.csv')

user_data2 = user_data.copy()
user_data2.head(5)
# Out:
#    user_id                   name   username                         email  \
# 0        1     Eniayomi Oluwaseyi   eniayomi   oluwaseyieniayomi@gmail.com
# 1        2          Elijah Okokon    DMatrix           okoelijah@gmail.com
# 2        3           Jeffrey Ogah  jeff.ogah           jeff.ogah@gmail.com
# 3        4  Oluwaseyi Oluwapelumi     nathan     nathanoluwaseyi@gmail.com
# 4        5                   PoRH      lamar  paulchibiukeigweze@gmail.com
#
#                                                image provider   provider_id  \
# 0  /storage/oluwaseyieniayomi/images//5lxMjdbOVca...   google  1.010000e+20
# 1  /storage/2/images//DB7axhFJpFUzPuCNPRMQ6X1iNwb...   google  1.060000e+20
# 2  https://lh3.googleusercontent.com/-FQgpN5l_UoY...   google  1.010000e+20
# 3  /storage/4/images/thumbnail/TLWSEBK7C-UMECCGUP...   google  1.070000e+20
# 4  /storage/5/images/thumbnail/images (2)_small_1...   google  1.030000e+20
#
#    password                                     remember_token  \
# 0       NaN  79kIhqDiWzqx1i3eFpGMpxfLdPVIvSfv8A3vN2PNEl4ig9...
# 1       NaN  Rz08FtDtdyAp8Cm5XJq5XumgZhEqytSu5MxxyHZYlHBhd0...
# 2       NaN  ZxNMYG05B6RQuSWaJlqlc8bGbPyFxNGNnNf5D86biFix4G...
# 3       NaN  uxbOXr4Cw8tJyilWDKQRhi7TjiV7gBzjMnX0cb4i3ndFu6...
# 4       NaN  EeCB77oXHo3zdZgYTVhWlw2EyHkTtLSJb2PjWFF9RuG7H1...
#
#        created_at      updated_at  \
# 0  8/1/2019 17:57  8/1/2019 17:57
# 1  8/1/2019 18:05  8/1/2019 18:05
# 2  8/1/2019 20:55  8/1/2019 20:55
# 3  8/2/2019 16:52  8/2/2019 16:52
# 4  8/3/2019 11:33  8/3/2019 11:33
#
#                                            short_bio
# 0               Software Developer | DevOPs Engineer
# 1                                      Web Developer
# 2  Front End Developer | React Developer | Mentor...
# 3  | Software Developer | DevOps Engineer | @linu...
# 4            I Am lamar and you don't think am real?

# %%
user_data2.dtypes
# Out:
# user_id             int64
# name               object
# username           object
# email              object
# image              object
# provider           object
# provider_id       float64
# password          float64
# remember_token     object
# created_at         object
# updated_at         object
# short_bio          object
# dtype: object

# %%
#merging user and post data on user_id

df = pd.merge(post_data2, user_data2, on='user_id')

# %%
#copying merged data

metadata = df.copy()

df.head(5)
# Out:
#    id  user_id                              title  \
# 0   1     2077  What i have learnt so far on HTML
# 1   2     1719                   HTML BEGINS HERE
# 2   4     1310            My Laziness In The Open
# 3   6     1787                          MY TASK 2
# 4  11     1787                          MY TASK 2
#
#                                              content        tags  \
# 0  I learnt how to use the table tag as i have us...         NaN
# 1   I am on this journey with start.ng, and here ...  Technology
# 2  I have not been attending classes on the HNG c...         NaN
# 3  My journey on **StartNG** pre-internship progr...         NaN
# 4  My journey on **StartNG** pre-internship progr...        html
#
#                                     slug     created_at_x     updated_at_x  \
# 0  what-i-have-learnt-so-far-on-html-985  8/25/2019 19:39  8/28/2019 11:30
# 1                   html-begins-here-4d6  8/25/2019 19:44  8/28/2019 11:30
# 2            my-laziness-in-the-open-029  8/25/2019 19:50  8/28/2019 11:30
# 3                          my-task-2-649  8/25/2019 19:51  8/28/2019 11:30
# 4                          my-task-2-649  8/25/2019 19:57  8/28/2019 11:30
#
#   image_x  status_id                        ...                          \
# 0       1        NaN                        ...
# 1       1        NaN                        ...
# 2       1        NaN                        ...
# 3       1        NaN                        ...
# 4       1        NaN                        ...
#
#            username                        email  \
# 0        obiako4u53         obiako4u53@gmail.com
# 1      kolawolejohn    kolawole.oajohn@gmail.com
# 2           Oladele  makanjuolaoladele@gmail.com
# 3  emmanuel.ulaka16   emmanuel.ulaka16@gmail.com
# 4  emmanuel.ulaka16   emmanuel.ulaka16@gmail.com
#
#                                              image_y provider   provider_id  \
# 0  https://lh3.googleusercontent.com/-Gnb2o4SA6HU...   google  1.090000e+20
# 1  /storage/kolawolejohn/images//h3OofJbAD9cW5Ro9...   google  1.130000e+20
# 2  /storage/Oladele/images//irm5vHnrgL2XD3bvmhZR5...   google  1.140000e+20
# 3  /storage/1787/images//8RueyRdHpIdJdBZ5I7DWpU7i...   google  1.100000e+20
# 4  /storage/1787/images//8RueyRdHpIdJdBZ5I7DWpU7i...   google  1.100000e+20
#
#   password                                     remember_token  \
# 0      NaN  TitXROeUlC4a4c9VVpaIhfbAu5dPWVC2PrN5lLufalPFbx...
# 1      NaN  GeEAAszJ1jjHBXZWwv0ujB1arkHJVMDveiRZSCSfRV4e0Q...
# 2      NaN  ArBKC0Ons7Xy3G8llXn6MqcwiDKZxOFPibMlzzY1Lau4Yk...
# 3      NaN  B56rhxElOxeJ1BPqj3qJsVz6TzVuc5S6hrOKlpQ1L1fgfr...
# 4      NaN  B56rhxElOxeJ1BPqj3qJsVz6TzVuc5S6hrOKlpQ1L1fgfr...
#
#       created_at_y     updated_at_y  \
# 0  8/20/2019 22:28  8/20/2019 22:28
# 1  8/19/2019 21:42  8/19/2019 21:42
# 2  8/19/2019 12:31  8/19/2019 12:31
# 3   8/20/2019 0:45   8/20/2019 0:45
# 4   8/20/2019 0:45   8/20/2019 0:45
#
#                                            short_bio
# 0  I am a person of Growth mindset. I believe i c...
# 1  I am Kolawole Adebayo Ogunfowokan, I am a trai...
# 2                               Front-End enthusiast
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 23 columns]

# %%
metadata.dtypes
# Out:
# id                  int64
# user_id             int64
# title              object
# content            object
# tags               object
# slug               object
# created_at_x       object
# updated_at_x       object
# image_x            object
# status_id         float64
# action             object
# post_id           float64
# name               object
# username           object
# email              object
# image_y            object
# provider           object
# provider_id       float64
# password          float64
# remember_token     object
# created_at_y       object
# updated_at_y       object
# short_bio          object
# dtype: object

# %%
metadata.shape
# Out:
# (876, 23)

# %%
metadata.describe()
# Out:
#                 id      user_id  status_id  post_id   provider_id  password
# count   876.000000   876.000000        0.0      0.0  8.760000e+02       0.0
# mean    516.808219  1061.639269        NaN      NaN  1.088744e+20       NaN
# std     278.648058   788.070779        NaN      NaN  5.313937e+18       NaN
# min       1.000000     1.000000        NaN      NaN  1.000000e+20       NaN
# 25%     278.750000   338.000000        NaN      NaN  1.040000e+20       NaN
# 50%     523.500000   944.000000        NaN      NaN  1.090000e+20       NaN
# 75%     754.250000  1836.250000        NaN      NaN  1.130000e+20       NaN
# max    1007.000000  2297.000000        NaN      NaN  1.180000e+20       NaN

# %%
#data with missing columns

metadata.isnull().sum()
# Out:
# id                  0
# user_id             0
# title               0
# content             0
# tags              694
# slug                0
# created_at_x        0
# updated_at_x        0
# image_x           476
# status_id         876
# action            871
# post_id           876
# name                0
# username            0
# email               0
# image_y             0
# provider            0
# provider_id         0
# password          876
# remember_token      0
# created_at_y        0
# updated_at_y        0
# short_bio         246
# dtype: int64

# %%
#dropping missing columns

metadata.dropna(axis=1, inplace=True)

# %%
metadata.isnull().sum()
# Out:
# id                0
# user_id           0
# title             0
# content           0
# slug              0
# created_at_x      0
# updated_at_x      0
# name              0
# username          0
# email             0
# image_y           0
# provider          0
# provider_id       0
# remember_token    0
# created_at_y      0
# updated_at_y      0
# dtype: int64

# %%
metadata.describe()
# Out:
#                 id      user_id   provider_id
# count   876.000000   876.000000  8.760000e+02
# mean    516.808219  1061.639269  1.088744e+20
# std     278.648058   788.070779  5.313937e+18
# min       1.000000     1.000000  1.000000e+20
# 25%     278.750000   338.000000  1.040000e+20
# 50%     523.500000   944.000000  1.090000e+20
# 75%     754.250000  1836.250000  1.130000e+20
# max    1007.000000  2297.000000  1.180000e+20

# %%
pandas_profiling.ProfileReport(metadata)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>16 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>876 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>116.3 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>136.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>3 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>12 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_content"><code>content</code></a> has a high cardinality: 743 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_created_at_x"><code>created_at_x</code></a> has a high cardinality: 387 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_created_at_y"><code>created_at_y</code></a> has a high cardinality: 280 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_email"><code>email</code></a> has a high cardinality: 308 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_image_y"><code>image_y</code></a> has a high cardinality: 308 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_name"><code>name</code></a> has a high cardinality: 307 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_provider"><code>provider</code></a> has constant value google <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_remember_token"><code>remember_token</code></a> has a high cardinality: 308 distinct values  <span class="label label-warning">Warning</span></li

# %%
#finding correlation

metadata.corr(method = 'pearson')
# Out:
#                    id   user_id  provider_id
# id           1.000000 -0.165137    -0.095062
# user_id     -0.165137  1.000000     0.096054
# provider_id -0.095062  0.096054     1.000000

# %%
#finding correlation

metadata.corr(method = 'kendall')
# Out:
#                    id   user_id  provider_id
# id           1.000000 -0.104611    -0.069794
# user_id     -0.104611  1.000000     0.084080
# provider_id -0.069794  0.084080     1.000000

# %%
import seaborn as sb
import matplotlib.pyplot as plt
metadata.columns
# Out:
# Index(['id', 'user_id', 'title', 'content', 'slug', 'created_at_x',
#        'updated_at_x', 'name', 'username', 'email', 'image_y', 'provider',
#        'provider_id', 'remember_token', 'created_at_y', 'updated_at_y'],
#       dtype='object')

# %%
#Getting the TF-IDF score or frequency of a word occurring in a document, i.e the title

tfidf_matrix = tfidf.fit_transform(metadata['content'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (876, 5122)

# %%
#compute users similarity score using the cosine similarity
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#defining a function that takes in a post title as an input and outputs a list of the 10 most similar post.Firstly, for this, you need a reverse mapping of movie titles and DataFrame indices. In other words, you need a mechanism to identify the index of a movie in your metadata DataFrame, given its title.


#Construct a reverse map of indices and movie titles
indices = pd.Series(metadata.index, index=metadata['title']).drop_duplicates()

#Get the index of the post given its title.

#Get the list of cosine similarity scores for that particular post with all posts. Convert it into a list of tuples where the first element is its position and the second is the similarity score.


#Sort the aforementioned list of tuples based on the similarity scores; that is, the second element.

#Get the top 10 elements of this list. Ignore the first element as it refers to self (the post most similar to a particular post is the post itself).

#Return the titles corresponding to the indices of the top elements.

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return metadata['title'].iloc[movie_indices]
get_recommendations('What i have learnt so far on HTML')
# Out:
# 265                              third
# 308            WHAT I'VE LEARNT SO FAR
# 775                             TASK 2
# 776                             TASK 2
# 141                      CV Using html
# 261                               TEst
# 237           Startng task 2 Completed
# 28     WHAT I HAVE DONE SO FAR ON HTML
# 16                  What I done so far
# 51        Lucid post to start.ng Task1
# Name: title, dtype: object

# %%
get_recommendations('Welcome to Lucid')
# Out:
# 571                    pre- intership on startng
# 590                                        ochem
# 464                      my 2nd task on start.ng
# 465                      my 2nd task on start.ng
# 615                                My First Post
# 582                               Test an image.
# 449         Converting Cv to Html StartNg Task 2
# 502                      Journey round the world
# 504                               Journey so far
# 574    THE SKY IS MY STEPPING STONE WITH STARTNG
# Name: title, dtype: object

# %%
metadata.title
# Out:
# 0                      What i have learnt so far on HTML
# 1                                       HTML BEGINS HERE
# 2                                My Laziness In The Open
# 3                                              MY TASK 2
# 4                                              MY TASK 2
# 5                                                 Task 2
# 6                                Daily Log - CLASS DAY 1
# 7                                     My Journey on HTML
# 8                                            Please note
# 9                                     My Journey on HTML
# 10                                    My learning so far
# 11                               StartNG HTML Exposition
# 12                                     StartNG HTML task
# 13                             On StartNG Pre-Internship
# 14                                                   why
# 15                         HNG internship journey so far
# 16                                    What I done so far
# 17                             Learnt Learn and Learning
# 18                      How far we can go with just HTML
# 19                   Learning Web development at StartNg
# 20     The Journey with StartNG: Creating my CV with ...
# 21     The Journey with StartNG: Creating my CV with ...
# 22                                    The Journey So Far
# 23                                    The Journey So Far
# 24                                    The Journey So Far
# 25                   What i have done so far on start.ng
# 26                                         Task Number 7
# 27                          What has been learnt so far?
# 28                       WHAT I HAVE DONE SO FAR ON HTML
# 29                                                TASK 2
#                              ...
# 846                           software testing for lucid
# 847                                      My html project
# 848                                      My html project
# 849                                    My Start.ng story
# 850    Overcoming the Rough Road to Front End Develop...
# 851    We Finally Have a Carbon-dioxide-filled Market...
# 852     How Not to Miss Important Information on StartNG
# 853                  User Acceptance Testing Using Lucid
# 854                                 HNGInternship6 Rules
# 855                                        StartNG Class
# 856                                   MY HTML EXPERIENCE
# 857                           ELLA'S START-NG EXPERIENCE
# 858                                           Post title
# 859                                            html test
# 860                  YOUR HIGH IQ WILL KILL YOUR STARTUP
# 861    A CHINESE VILLAGER WHO SELLS MORE SOFTWARE DAI...
# 862                BUILD AROUND YOUR DISCOVERY MECHANISM
# 863                      DON'T ASK WHY YOU WERE REJECTED
# 864                                        THE SUNFLOWER
# 865                                     Welcome to Lucid
# 866                                        This is lucid
# 867                                  this is a test post
# 868                                         this is mine
# 869                                 Your face PHP script
# 870                                         with picture
# 871                                 Post with two images
# 872                                                 asda
# 873                                       Speed Of Light
# 874                                                Am ok
# 875                                            jbhjkhkbb
# Name: title, Length: 876, dtype: object

# %%
metadata.shape
# Out:
# (876, 16)

# %%
#uploading the following data
following_data = pd.read_csv('following.csv')

following_data.head()
# Out:
#    user_id  follower_id  status
# 0        3            6       1
# 1        6            3       1
# 2        3            2       1
# 3        3            7       1
# 4        7            2       1

# %%
following_data.describe()
# Out:
#            user_id  follower_id       status
# count  5296.000000  5296.000000  5296.000000
# mean    793.865370   695.724887     0.976020
# std     518.974621   520.907520     0.153002
# min       1.000000     1.000000     0.000000
# 25%     353.000000   218.000000     1.000000
# 50%     722.000000   642.000000     1.000000
# 75%    1161.000000  1075.000000     1.000000
# max    2287.000000  2218.000000     1.000000

# %%
#merging metadata and following_data

df2 = pd.merge(metadata, following_data, on='user_id')

# %%
df2.isnull().sum()
# Out:
# id                0
# user_id           0
# title             0
# content           0
# slug              0
# created_at_x      0
# updated_at_x      0
# name              0
# username          0
# email             0
# image_y           0
# provider          0
# provider_id       0
# remember_token    0
# created_at_y      0
# updated_at_y      0
# follower_id       0
# status            0
# dtype: int64

# %%
df2.shape
# Out:
# (4099, 18)

# %%
#copying df2 

metadata2 = df2.copy()

# %%
metadata2.head(5)
# Out:
#    id  user_id   title                                            content  \
# 0   7      167  Task 2   A Summary on The “idongesit.html” CV, Its Str...
# 1   7      167  Task 2   A Summary on The “idongesit.html” CV, Its Str...
# 2   7      167  Task 2   A Summary on The “idongesit.html” CV, Its Str...
# 3   7      167  Task 2   A Summary on The “idongesit.html” CV, Its Str...
# 4   7      167  Task 2   A Summary on The “idongesit.html” CV, Its Str...
#
#          slug     created_at_x     updated_at_x              name  \
# 0  task-2-7e5  8/25/2019 19:51  8/28/2019 11:30  Idongesit Essien
# 1  task-2-7e5  8/25/2019 19:51  8/28/2019 11:30  Idongesit Essien
# 2  task-2-7e5  8/25/2019 19:51  8/28/2019 11:30  Idongesit Essien
# 3  task-2-7e5  8/25/2019 19:51  8/28/2019 11:30  Idongesit Essien
# 4  task-2-7e5  8/25/2019 19:51  8/28/2019 11:30  Idongesit Essien
#
#           username                   email  \
# 0  idongesitessien  ceoidessien7@gmail.com
# 1  idongesitessien  ceoidessien7@gmail.com
# 2  idongesitessien  ceoidessien7@gmail.com
# 3  idongesitessien  ceoidessien7@gmail.com
# 4  idongesitessien  ceoidessien7@gmail.com
#
#                                              image_y provider   provider_id  \
# 0  /storage/idongesitessien/images//LmQIohc93loeh...   google  1.100000e+20
# 1  /storage/idongesitessien/images//LmQIohc93loeh...   google  1.100000e+20
# 2  /storage/idongesitessien/images//LmQIohc93loeh...   google  1.100000e+20
# 3  /storage/idongesitessien/images//LmQIohc93loeh...   google  1.100000e+20
# 4  /storage/idongesitessien/images//LmQIohc93loeh...   google  1.100000e+20
#
#                                       remember_token     created_at_y  \
# 0  IQcHdoYWw51zMM3il8dypFQJbabDtX44smofDYDAd64qtf...  8/18/2019 21:58
# 1  IQcHdoYWw51zMM3il8dypFQJbabDtX44smofDYDAd64qtf...  8/18/2019 21:58
# 2  IQcHdoYWw51zMM3il8dypFQJbabDtX44smofDYDAd64qtf...  8/18/2019 21:58
# 3  IQcHdoYWw51zMM3il8dypFQJbabDtX44smofDYDAd64qtf...  8/18/2019 21:58
# 4  IQcHdoYWw51zMM3il8dypFQJbabDtX44smofDYDAd64qtf...  8/18/2019 21:58
#
#       updated_at_y  follower_id  status
# 0  8/18/2019 21:58          290       1
# 1  8/18/2019 21:58         1235       1
# 2  8/18/2019 21:58          107       1
# 3  8/18/2019 21:58          101       1
# 4  8/18/2019 21:58            7       1

# %%
metadata2.columns
# Out:
# Index(['id', 'user_id', 'title', 'content', 'slug', 'created_at_x',
#        'updated_at_x', 'name', 'username', 'email', 'image_y', 'provider',
#        'provider_id', 'remember_token', 'created_at_y', 'updated_at_y',
#        'follower_id', 'status'],
#       dtype='object')

# %%
# Parse the stringified features into their corresponding python objects
from ast import literal_eval

metadata2['username'] = metadata2['username'].apply(literal_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-bf691f543c87> in <module>()
#       2 from ast import literal_eval
#       3
# ----> 4 metadata2['username'] = metadata2['username'].apply(literal_eval)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# ~\Anaconda3\lib\ast.py in literal_eval(node_or_string)
#      83                     return left - right
#      84         raise ValueError('malformed node or string: ' + repr(node))
# ---> 85     return _convert(node_or_string)
#      86
#      87
#
# ~\Anaconda3\lib\ast.py in _convert(node)
#      82                 else:
#      83                     return left - right
# ---> 84         raise ValueError('malformed node or string: ' + repr(node))
#      85     return _convert(node_or_string)
#      86
#
# ValueError: malformed node or string: <_ast.Name object at 0x000001B247D471D0>

# %%
#adding more metadata

def create_soup(x):
    return ' '.join(x['username'])

# %%
# Create a new soup feature
metadata2['soup'] = metadata.apply(create_soup, axis=1)

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(metadata2['soup'])
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# Reset index of your main DataFrame and construct reverse mapping as before
metadata2 = metadata2.reset_index()
indices = pd.Series(metadata.index, index=metadata['content'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-94883fc254ad> in <module>()
#       3
#       4 count = CountVectorizer(stop_words='english')
# ----> 5 count_matrix = count.fit_transform(metadata2['soup'])
#       6 # Compute the Cosine Similarity matrix based on the count_matrix
#       7 from sklearn.metrics.pairwise import cosine_similarity
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in decode(self, doc)
#     117
#     118         if doc is np.nan:
# --> 119             raise ValueError("np.nan is an invalid document, expected byte or "
#     120                              "unicode string.")
#     121
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.
